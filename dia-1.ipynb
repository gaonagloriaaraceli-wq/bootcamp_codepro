# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %%
nombre="Araceli"
edad=23
cuidad= "Asunción"
print(nombre,edad,cuidad)
# Out:
# Araceli 23 Asunción

# %%
#suma
cantidad_de_manzanas=20
cantidad_de_naranjas= 11
cantidad_de_frutas= cantidad_de_manzanas+cantidad_de_naranjas
print("La cantidad total de frutas es:", cantidad_de_frutas)


#resta
frutas_vendidas= 15
frutas_restantes= cantidad_de_frutas-frutas_vendidas
print("La cantidad de frutas restantes es: ",frutas_restantes)
# Out:
# La cantidad total de frutas es: 31
# La cantidad de frutas restantes es:  16

# %%
nombre="Sol"
apellido="Galeazzi"
print(f"Hola , me llamo {nombre} {apellido}. Mucho gusto.")
# Out:
# Hola , me llamo Sol Galeazzi. Mucho gusto.

# %%
cantidad_caramelos= int(input("Cuál es la cantidad de caramelos?"))
print(cantidad_caramelos)
cantidad_niños=int(input("Cuál es la cantidad de niños?"))
print(cantidad_niños)
cantidad_caramelos_niños= cantidad_caramelos/cantidad_niños
print(" A cada niño le corresponde",cantidad_caramelos_niños, "caramelos")

cantidad_restante_caramelos= cantidad_caramelos%cantidad_niños
print("La cantidad de caramelos restante es: ",cantidad_restante_caramelos)
# Out:
# 10
# 4
#  A cada niño le corresponde 2.5 caramelos
# La cantidad de caramelos restante es:  2

# %%
def saludo( ):
    rutina1=(input("Qué es lo primero que haces a la mañana?"))
    rutina2=(input("Cuál es el segundo paso de tu rutina?"))
    rutina3=(input("Cuál es el último paso de tu rutina?"))
    print("Lo primero que hago es:", rutina1,",lo segundo es: ",rutina2,"y por último:",rutina3)
saludo()
saludo()
saludo()
# Out:
# Lo primero que hago es: leventarme y realizar estiramientos ,lo segundo es:  ir al baño y cepillarme los dientes y por último: tomar un vaso de agua
# Lo primero que hago es: levantarme y ver el celular ,lo segundo es:  darle de comer a mi gato y por último: prepararme el desayuno , desayunar y lavar los cubiertos
# Lo primero que hago es: levantarme e ir a cepillarme  ,lo segundo es:  salir a tomar sol y por último: preparar el desayuno , desayunar , lavar los cubiertos y organizar el dia

# %%
nombre_auto= input("Ingrese el auto de su interés")
cantidad_de_pedido=int(input("Cuántos autos desea de ese modelo?"))

def auto_modelo(nombre,cantidad):
    print(f"El modelo es: {nombre} y desea: {cantidad} autos del mismo modelo")
    print( "Esta listo para retirar ")

auto_modelo(nombre_auto,cantidad_de_pedido)
# Out:
# El modelo es: Toyota Allion y desea: 4 autos del mismo modelo
# Esta listo para retirar

# %%
precio_producto=int(input("Ingrese el precio del producto"))
impuesto_global= 10
caclular_total=precio_producto+impuesto_global

def precio_total(precio,impuesto,total):
    print(f"El precio del producto es: {precio} el impuesto tiene un valor de {impuesto}, entonces el precio total es de {total}")
    print(f"El precio total es:{total}")
precio_total(precio_producto,impuesto_global,caclular_total)
# Out:
# El precio del producto es: 19990 el impuesto tiene un valor de 10, entonces el precio total es de 20000
# El precio total es:20000
