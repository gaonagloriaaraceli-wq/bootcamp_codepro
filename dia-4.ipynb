# %% [markdown]
# Challenge 1 🤺
# Escribir un programa que cree un diccionario vacío y lo vaya llenado con información sobre una persona (por ejemplo nombre, edad, sexo, teléfono, correo electrónico, etc.) que se le pida al usuario.
#
# Cada vez que se añada un nuevo dato debe imprimirse el contenido del diccionario.

# %%
mi_informacion={}

mi_informacion=("nombre:"" Araceli")
print(mi_informacion)
mi_informacion=("edad:"" 23 años")
print(mi_informacion)
mi_informacion=("sexo:"" femenino")
print(mi_informacion)
mi_informacion=("telefono:"" 0972634010")
print(mi_informacion)
mi_informacion=("correo:"" gaonagloriaaraceli@gmail.com")
print(mi_informacion)
# Out:
# nombre: Araceli
# edad: 23 años
# sexo: femenino
# telefono: 0972634010
# correo: gaonagloriaaraceli@gmail.com

# %%
informacion_usuario={}
print(informacion_usuario)

nombre_usuario=input("Ingrese su nombre")
informacion_usuario["nombre"]=nombre_usuario
print(informacion_usuario)


edad_usuario=input("Ingrese su edad")
informacion_usuario["edad"]=edad_usuario
print(informacion_usuario)


sexo_usuario=input("Ingrese su sexo")
informacion_usuario["sexo"]=sexo_usuario
print(informacion_usuario)


telefono_usuario=input("Ingrese su telefono")
informacion_usuario["telefono"]=telefono_usuario
print(informacion_usuario)


correo_usuario=input("Ingrese su correo")
informacion_usuario["correo"]=correo_usuario
print(informacion_usuario)

# %% [markdown]
# Challenge 2 🤺
# Crear una tarjeta personal. El usuario (mediante input) puede elegir:
#
# Crear datos nuevos
# Modificar datos
# Eliminar datos

# %%
tarjeta_personal={}
opcion_usuario= input("Ingrese su opción")

if opcion_usuario=="1":
    clave_usuario=input("Ingrese la clave")
    valor_usuario=input("Ingrese el valor")
    tarjeta_personal [clave_usuario]= valor_usuario
    print(tarjeta_personal)
elif opcion_usuario=="2":
     print(tarjeta_personal)
     clave_usuario=input("Ingrese la clave")
    valor_usuario=input("Ingrese el valor")
    tarjeta_personal [clave_usuario]= valor_usuario
# Out:
# {'nombre': 'Araceli'}

# %%
agenda_contactos={"Ara:numero: 0972634010,mail:gloriaaraceli@gmail.com"}
print(agenda_contactos)
# Out:
# {'Ara:numero: 0972634010,mail:gloriaaraceli@gmail.com'}

# %%
if opciones_usuario=="1":
    nombre_contacto=input("Ingrese nombre del contacto")
    numero_contacto=input("Ingrese número del contacto")
    agenda_contactos[nombre_usuario]=numero_contacto
    print(agenda_contactos)
elif opciones_usuario=="2":
    print(agenda_contactos)
