# %%
#definimos la clase
# class Animal:
   # especie= "Ave"
  #  alas=2
   # pico=1
   # ojos=2
   # def __init__(self,nombre,color):
    #    self.nombre= nombre
     #   self.color= color 

#ave1=Animal("Lina","verde")


#print(f"Me llamo {ave1.nombre} y soy un ave de color {ave1.color}")
# Out:
# Me llamo Lina y soy un ave de color verde

# %%
class Animales:
    especie="mamifero"
    patas=4
    orejas=2
    ojos=2
    nariz=1

    def __init__ (self,nombre,color):
        self.nombre= nombre 
        self.color=color 

    def sonidos(self,sonidos):
        self.sonido="miaumiau"

    def movimiento(self,movimiento):
        self.mover="muevo la cola"


mamifero1=Animales("Gato","blanco con rayas grises y negras")

print(f"Soy un {mamifero1.nombre} de color {mamifero1.color} cuando hablo,digo {mamifero1.sonidos}, cuando me muevo {mamifero1.movimiento}")
# Out:
# Soy un Gato de color blanco con rayas grises y negras cuando hablo,digo <bound method Animales.sonidos of <__main__.Animales object at 0x00000273F8F94BD0>>, cuando me muevo <bound method Animales.movimiento of <__main__.Animales object at 0x00000273F8F94BD0>>

# %%
class Perro:
    patas=4 
    orejas=2
    ojos=2
    nariz=1
    def __init__ (self,nombre,color):
        self.nombre= nombre 
        self.color=color 

    def ladrar(self):
        print("Cuando ladro digo guau guau")
    def correr(self):
        print("Me gusta correr trar la pelota")
        
class Raza (Perro): 
        def tirar(self):
            print("Cuando me enojo me gusta tirar fuego")
class Raza_grande(Perro):
        def volar(self):
            print("Cuando me subo a un arbol siento que puedo volar")

perro1=Perro("Sid","Marrón")
print(perro1.nombre)
print(perro1.color)
perro1.ladrar()
perro1.correr()
# Out:
# Sid
# Marrón
# Cuando ladro digo guau guau
# Me gusta correr trar la pelota

# %%
class Personaje:
    def __init__(self,historia):
        self.historia=historia 

class Heroe(Personaje):
    def volar(self):
        print("puedo volar muy alto y super rápido")
class Villano(Personaje):
    def fuerza(self):
        print("tengo super fuerza y no podrás vencerme")

historia1=Personaje("Historia: Super poderes")
print(historia1.historia)



heroe1=Heroe("Super poderes")
heroe1.volar()

villano1=Villano("Super poderes")
villano1.fuerza()

print(!)
# Out:
# Historia: Super poderes
# puedo volar muy alto y super rápido
# tengo super fuerza y no podrás vencerme
